# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_stata('/Users/grant/Downloads/PS5.dta')
# Out:
# /Users/grant/opt/anaconda3/lib/python3.9/site-packages/pandas/io/stata.py:1457: UnicodeWarning:
# One or more strings in the dta file could not be decoded using utf-8, and
# so the fallback encoding of latin-1 is being used.  This can happen when a file
# has been incorrectly encoded by Stata or some other software. You should verify
# the string values returned are correct.
#   warnings.warn(msg, UnicodeWarning)

# %%
df
# Out:
#        folio       income  treated  poor  frac_children_sick  HHsize age  \
# 0      11038  1103.030029      0.0   1.0                 1.0       5  32
# 1      42319    16.000000      1.0   0.0                 0.0       3  30
# 2     107473   559.515015      1.0   1.0                 1.0      10  60
# 3     107474   559.515015      1.0   1.0                 0.0       8  31
# 4     107475    16.000000      1.0   1.0                 1.0       4  32
# ...      ...          ...      ...   ...                 ...     ...  ..
# 9313  697867   667.218018      1.0   1.0                 0.0      16  63
# 9314  697868    16.000000      1.0   1.0                 0.0       9  34
# 9315  697869   885.624023      1.0   1.0                 1.0       8  57
# 9316  697871   885.624023      1.0   1.0                 0.0      10  47
# 9317  697872   276.887207      1.0   1.0                 0.0       6  69
#
#         male
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
# ...

# %%
X = df[['age', 'frac_children_sick']]
y = df['income']
X = sm.add_constant(X)

model = sm.OLS(y, X).fit()
predictions = model.predict(X)
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/bz/tzynj7lj1y94x5nys6hlwmtr0000gn/T/ipykernel_88208/3511353384.py in <module>
#       1 X = df[['age', 'frac_children_sick']]
#       2 y = df['income']
# ----> 3 X = sm.add_constant(X)
#       4
#       5 model = sm.OLS(y, X).fit()
#
# NameError: name 'sm' is not defined

# %%
model

# %%
fig, axes = plt.subplots(1,1, figsize = (40,20))

axes.plot([i for i in range(100)], predictions[:100]);
